# %%
# %cd /content/drive/MyDrive/Project B/DatasetCondensation-master
sys.path.append('/content/drive/MyDrive/Project B/DatasetCondensation-master')
import sys
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
import scipy.io as so
# Out:
# /content/drive/MyDrive/Project B/DatasetCondensation-master

# %% [markdown]
# change the dataset and initialization method according to the project description

# %%
# !python main_DM.py --save_path 'result_DM' --num_eval 100 --epoch_eval_train 300 --Iteration 1000 --ipc 10 --dataset MNIST --init real
# Out:
# eval_it_pool:  [0, 2000, 4000, 6000, 8000, 10000, 12000, 14000, 16000, 18000, 20000]
# Files already downloaded and verified
# Files already downloaded and verified
#
# ================== Exp 0 ==================
#
# Hyper-parameters:
#  {'dataset': 'CIFAR10', 'model': 'ConvNet', 'ipc': 10, 'eval_mode': 'SS', 'num_exp': 1, 'num_eval': 100, 'epoch_eval_train': 1000, 'Iteration': 20000, 'lr_img': 1.0, 'lr_net': 0.01, 'batch_real': 256, 'batch_train': 256, 'init': 'real', 'dsa_strategy': 'color_crop_cutout_flip_scale_rotate', 'data_path': 'data', 'save_path': 'result_DM', 'dis_metric': 'ours', 'method': 'DM', 'outer_loop': 10, 'inner_loop': 50, 'device': 'cuda', 'dsa_param': <utils.ParamDiffAug object at 0x7f9881f3ba00>, 'dsa': True}
# Evaluation model pool:  ['ConvNet']
# class c = 0: 5000 real images
# class c = 1: 5000 real images
# class c = 2: 5000 real images
# class c = 3: 5000 real images
# class c = 4: 5000 real images
# class c = 5: 5000 real images
# ...
